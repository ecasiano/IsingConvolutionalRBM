# %% [markdown]
# ## RBM's in Pytorch

# %%
import numpy as np
import pandas as pd
import torch
import torch.utils.data
from torch.utils.data import Dataset,DataLoader
import torch.nn as nn
import torch.nn.functional
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../')
import ising_analysis
import importlib
importlib.reload(ising_analysis)
# Out:
# <module 'ising_analysis' from '../ising_analysis.py'>

# %%
# Turn debuggers off once model is... debugged
torch.autograd.set_detect_anomaly(False)
torch.autograd.profiler.profile(False)
torch.autograd.profiler.emit_nvtx(False)

# %%
# Set pytorch random seed
torch.manual_seed(0)

# %% [markdown]
# ## Define the model
#
# Energy:
# \begin{equation}
# E(\sigma,h) = -\sum_{i,j,\alpha} W_{(i-j),\alpha} \sigma_i h_{j,\alpha} -B \sum_i \sigma_i -\sum_{j,\alpha} c_{\alpha} h_{j,\alpha}
# \end{equation}
#
# Free energy:
# \begin{equation}
# \varepsilon(\sigma) = -B \sum_{i=1}^{N} \sigma_i -\sum_{\alpha=1}^M \sum_{j=1}^{N} \ln (1+e^{c_{\alpha}+\sum_{i=1}^{N}W_{(i-j),\alpha}\sigma_i})
# \end{equation}
#
# $L$: linear size
#
# $N$: total spins
#
# $M$: hidden neurons per spin
#
# $\sigma_i$: spin unit
#
# $h_{j,\alpha}$: hidden unit
#
# $W_{(i-j),\alpha}$: weight
#
# $i,j \in [0,N-1]$
#
# $\alpha \in [0,M-1]$

# %%
# Define model
class RBM(nn.Module):
   def __init__(self,
               n_vis,
               n_hin,
               k=5):
        super(RBM, self).__init__()
        self.W = nn.Parameter(torch.randn(n_hin,n_vis)*1e-2)
        self.v_bias = nn.Parameter(torch.zeros(n_vis))
        self.h_bias = nn.Parameter(torch.zeros(n_hin))
        self.k = k
    
   def sample_from_p(self,p):
       return torch.nn.functional.relu(torch.sign(p - Variable(torch.rand(p.size()))))
    
   def v_to_h(self,v):
        p_h = torch.sigmoid(torch.nn.functional.linear(v,self.W,self.h_bias))
        sample_h = self.sample_from_p(p_h)
        return p_h,sample_h
    
   def h_to_v(self,h):
        p_v = torch.sigmoid(torch.nn.functional.linear(h,self.W.t(),self.v_bias))
        sample_v = self.sample_from_p(p_v)
        return p_v,sample_v
        
   def forward(self,v):
        pre_h1,h1 = self.v_to_h(v)
        
        h_ = h1
        for _ in range(self.k):
            pre_v_,v_ = self.h_to_v(h_)
            pre_h_,h_ = self.v_to_h(v_)
        
        return v,v_
    
   def free_energy(self,v):
        vbias_term = v.mv(self.v_bias)
        wx_b = torch.nn.functional.linear(v,self.W,self.h_bias)
        hidden_term = wx_b.exp().add(1).log().sum(1)
        return (-hidden_term - vbias_term).mean()

# %%
# Create Ising Dataset object from Monte Carlo data
class CustomIsingDataset(Dataset):
    def __init__(self,spins):
        self.spins = spins
        
    def __len__(self):
        return len(self.spins)
    
    def __getitem__(self,idx):
        spins = self.spins[idx]
        sample = {'spins': spins}
        return sample

# %%
# Specify the linear size and temperature
L = 8
T = 4.0

# %%
# Load spin data
filename_mc_spins = '../uncorrelated_monte_carlo_data/L_'+str(L)+'_T_'+str(T)+'_spins_seed_0.dat'

# Load data from file
spins = np.loadtxt(filename_mc_spins,dtype=np.float32) # network training sometimes breaks for 'double'

# Convert -1's to 0's for RBM compatibility
spins[spins==-1] = 0

# Convert to Python list for dataframe promotion simplicity
spins = list(spins)

# Convert spin data to pandas dataframe
spins_df = pd.DataFrame({'spins':spins})

# Create Dataset object
spins_dataset = CustomIsingDataset(spins_df['spins'])

# %%
# Show first few rows of loaded Monte Carlo configurations
plt.imshow(spins[0:20])

# %% [markdown]
# ## Check Monte Carlo data

# %%
filename_mc = '../uncorrelated_monte_carlo_data/L_'+str(L)+'_T_'+str(T)+'_seed_0.dat'

mc_data = np.loadtxt(filename_mc)
mc_e = mc_data[:,0] / L**2

# Plot running average of energy per spin
plt.plot(np.arange(mc_e.shape[0]),np.cumsum(mc_e)/np.arange(1,mc_e.shape[0]+1),color='tab:blue')

plt.xlabel('sample number')
plt.ylabel(r'$E/N$')
plt.axhline(ising_analysis.e_exact_func(T),zorder=-1,color='k')

# %%
mc_m = mc_data[:,1] / L**2

# Plot running average of energy per spin
plt.plot(np.arange(mc_m.shape[0]),np.cumsum(mc_m)/np.arange(1,mc_m.shape[0]+1),color='tab:orange')

plt.xlabel('sample number')
plt.ylabel(r'$M/N$')
plt.axhline(np.nan_to_num(ising_analysis.m_exact_func(T)),zorder=-1,color='k')
# Out:
# ../ising_analysis.py:103: RuntimeWarning: invalid value encountered in double_scalars
#   return (1-(1-np.tanh(K)**2)**4/(16*np.tanh(K)**4))**(1/8)

# %%
spins_data = np.loadtxt(filename_mc_spins)
mc_e = np.zeros(spins_data.shape[0])

for i,config in enumerate(spins_data):
    
    # print(config)
    ising_lattice = config.reshape((L,L))
    
    mc_e[i] = ising_analysis.get_energy(ising_lattice,L)
    
mc_e /= L**2
 
# Plot running average of energy per spin
plt.plot(np.arange(mc_e.shape[0]),np.cumsum(mc_e)/np.arange(1,mc_e.shape[0]+1),color='tab:blue')

plt.xlabel('sample number')
plt.ylabel(r'$E/N$')
plt.axhline(ising_analysis.e_exact_func(T),zorder=-1,color='k')

# %%
spins_data = np.loadtxt(filename_mc_spins)
mc_m = np.zeros(spins_data.shape[0])

for i,config in enumerate(spins_data):
    
    # print(config)
    ising_lattice = config.reshape((L,L))
    
    mc_m[i] = ising_analysis.get_magnetization(ising_lattice,L)
    
mc_m /= L**2
 
# Plot running average of energy per spin
plt.plot(np.arange(mc_m.shape[0]),np.cumsum(mc_m)/np.arange(1,mc_m.shape[0]+1),color='tab:orange')

plt.xlabel('sample number')
plt.ylabel(r'$M/N$')
plt.axhline(np.nan_to_num(ising_analysis.m_exact_func(T)),zorder=-1,color='k')
# Out:
# ../ising_analysis.py:103: RuntimeWarning: invalid value encountered in double_scalars
#   return (1-(1-np.tanh(K)**2)**4/(16*np.tanh(K)**4))**(1/8)

# %% [markdown]
# ## Perform train/test split of full dataset

# %%
N_full = len(spins_dataset) # total length of full dataset
N_train = int(N_full*1.0)
N_test = N_full - N_train

print("Full set: ", N_full,'\n')
print("Train set: ", N_train)
print("Test set: ", N_test,'\n')

# To use random_split(), lengths of train/test sets must add up to full. Check.
if (N_train + N_test == N_full): print('Good! Length of splitted sets adds up to full length.')
# Out:
# Full set:  16000
#
# Train set:  16000
# Test set:  0
#
# Good! Length of splitted sets adds up to full length.

# %%
# Perform random non-overlapping train/test split
train_spins,test_spins = torch.utils.data.random_split(spins_dataset,[N_train,N_test])

# %% [markdown]
# ## Initialize and train the model

# %%
# Network hyperparamters
N_spins = L**2
n_vis = N_spins
n_hin = N_spins

# %%
n_hin
# Out:
# 64

# %%
# %%time

# Training parameters
epochs = 5000
η = 0.01
batch_size = 50

# Define train and test DataLoaders
train_loader = DataLoader(train_spins, batch_size=batch_size, shuffle=True, num_workers=0)

rbm = RBM(n_vis,n_hin,k=1)
train_op = optim.SGD(rbm.parameters(),η)

loss_at_epoch = []
epoch = 0
counter = 0

# free_energy_old = 
for epoch in range(epochs):
    loss_ = []
    for idx, data in enumerate(train_loader): # iterates over batch
        
        sample_data = data['spins']
        # sample_data = Variable(data.view(-1,n_vis)) # This is like a np.reshape(), might be unnecessary
        
        counter += 1
        v,v1 = rbm(sample_data) # v: input, v1: generated
        loss = rbm.free_energy(v) - rbm.free_energy(v1)
        loss_.append(loss.data)
        train_op.zero_grad()
        loss.backward()
        train_op.step()
    
    mean_loss = np.mean(loss_)
    loss_at_epoch.append(np.mean(loss_)) # might need to loss_.detach()
    if epoch%10 == 0:
        print("Training loss for {} epoch: {}".format(epoch, np.mean(loss_)))
    epoch += 1
print("Training loss for {} epoch: {}".format(epoch, np.mean(loss_)))
# Out:
# Training loss for 0 epoch: 0.05160069465637207
# Training loss for 10 epoch: -0.6297455430030823
# Training loss for 20 epoch: -0.8536909222602844
# Training loss for 30 epoch: -0.9010286331176758
# Training loss for 40 epoch: -0.7932292222976685
# Training loss for 50 epoch: -0.49201130867004395
# Training loss for 60 epoch: -0.3986400067806244
# Training loss for 70 epoch: -0.49912065267562866
# Training loss for 80 epoch: -0.496425062417984
# Training loss for 90 epoch: -0.4849141240119934
# Training loss for 100 epoch: -0.43959441781044006
# Training loss for 110 epoch: -0.46197643876075745
# Training loss for 120 epoch: -0.5030648112297058
# Training loss for 130 epoch: -0.4262293875217438
# Training loss for 140 epoch: -0.3728190064430237
# Training loss for 150 epoch: -0.36060255765914917
# Training loss for 160 epoch: -0.30478984117507935
# Training loss for 170 epoch: -0.2670131027698517
# Training loss for 180 epoch: -0.2679717540740967
# Training loss for 190 epoch: -0.27275556325912476
# Training loss for 200 epoch: -0.3106794059276581
# Training loss for 210 epoch: -0.30290526151657104
# Training loss for 220 epoch: -0.28483840823173523
# Training loss for 230 epoch: -0.25348207354545593
# Training loss for 240 epoch: -0.3130708336830139
# Training loss for 250 epoch: -0.2954493761062622
# Training loss for 260 epoch: -0.2706180214881897
# Training loss for 270 epoch: -0.2793256938457489
# Training loss for 280 epoch: -0.29801470041275024
# Training loss for 290 epoch: -0.2929818630218506
# Training loss for 300 epoch: -0.26179999113082886
# Training loss for 310 epoch: -0.2789904475212097
# Training loss for 320 epoch: -0.2590928375720978
# Training loss for 330 epoch: -0.27594682574272156
# Training loss for 340 epoch: -0.2453831434249878
# Training loss for 350 epoch: -0.2753963768482208
# Training loss for 360 epoch: -0.23533523082733154
# Training loss for 370 epoch: -0.2397495061159134
# Training loss for 380 epoch: -0.25445136427879333
# Training loss for 390 epoch: -0.23345737159252167
# Training loss for 400 epoch: -0.20702645182609558
# Training loss for 410 epoch: -0.2553985118865967
# Training loss for 420 epoch: -0.2506876289844513
# Training loss for 430 epoch: -0.21875536441802979
# Training loss for 440 epoch: -0.20047564804553986
# Training loss for 450 epoch: -0.19628691673278809
# Training loss for 460 epoch: -0.18568602204322815
# Training loss for 470 epoch: -0.1572379320859909
# Training loss for 480 epoch: -0.18363790214061737
# Training loss for 490 epoch: -0.1497691571712494
# Training loss for 500 epoch: -0.17689642310142517
# Training loss for 510 epoch: -0.1756771057844162
# Training loss for 520 epoch: -0.18107807636260986
# Training loss for 530 epoch: -0.17251808941364288
# Training loss for 540 epoch: -0.15339788794517517
# Training loss for 550 epoch: -0.14722494781017303
# Training loss for 560 epoch: -0.14949063956737518
# Training loss for 570 epoch: -0.16450235247612
# Training loss for 580 epoch: -0.14534136652946472
# Training loss for 590 epoch: -0.14008621871471405
# Training loss for 600 epoch: -0.10993106663227081
# Training loss for 610 epoch: -0.16964498162269592
# Training loss for 620 epoch: -0.1570248156785965
# Training loss for 630 epoch: -0.16159363090991974
# Training loss for 640 epoch: -0.1239636167883873
# Training loss for 650 epoch: -0.10718202590942383
# Training loss for 660 epoch: -0.1575290709733963
# Training loss for 670 epoch: -0.09889163821935654
# Training loss for 680 epoch: -0.1402178555727005
# Training loss for 690 epoch: -0.1233706921339035
# Training loss for 700 epoch: -0.11435873806476593
# Training loss for 710 epoch: -0.13047130405902863
# Training loss for 720 epoch: -0.14639735221862793
# Training loss for 730 epoch: -0.07431526482105255
# Training loss for 740 epoch: -0.11330904811620712
# Training loss for 750 epoch: -0.11951978504657745
# Training loss for 760 epoch: -0.10099544376134872
# Training loss for 770 epoch: -0.10683751106262207
# Training loss for 780 epoch: -0.12351474910974503
# Training loss for 790 epoch: -0.09513554722070694
# Training loss for 800 epoch: -0.10789072513580322
# Training loss for 810 epoch: -0.10341940075159073
# Training loss for 820 epoch: -0.0686609297990799
# Training loss for 830 epoch: -0.10327382385730743
# Training loss for 840 epoch: -0.13816681504249573
# Training loss for 850 epoch: -0.11129207909107208
# Training loss for 860 epoch: -0.15192663669586182
# Training loss for 870 epoch: -0.09956593811511993
# Training loss for 880 epoch: -0.1044272631406784
# Training loss for 890 epoch: -0.10772745311260223
# Training loss for 900 epoch: -0.07994742691516876
# Training loss for 910 epoch: -0.0961499959230423
# Training loss for 920 epoch: -0.10916928946971893
# Training loss for 930 epoch: -0.07309379428625107
# Training loss for 940 epoch: -0.09570274502038956
# Training loss for 950 epoch: -0.12056402862071991
# Training loss for 960 epoch: -0.06973972171545029
# Training loss for 970 epoch: -0.11740128695964813
# Training loss for 980 epoch: -0.106053926050663
# Training loss for 990 epoch: -0.09501135349273682
# Training loss for 1000 epoch: -0.17087380588054657
# Training loss for 1010 epoch: -0.121529720723629
# Training loss for 1020 epoch: -0.0943218469619751
# Training loss for 1030 epoch: -0.07375051826238632
# Training loss for 1040 epoch: -0.08355651050806046
# Training loss for 1050 epoch: -0.0732024684548378
# Training loss for 1060 epoch: -0.08258982002735138
# Training loss for 1070 epoch: -0.08645214885473251
# Training loss for 1080 epoch: -0.10513301193714142
# Training loss for 1090 epoch: -0.1040327325463295
# Training loss for 1100 epoch: -0.08739902824163437
# Training loss for 1110 epoch: -0.1350233256816864
# Training loss for 1120 epoch: -0.1256200075149536
# Training loss for 1130 epoch: -0.08051307499408722
# Training loss for 1140 epoch: -0.08845102787017822
# Training loss for 1150 epoch: -0.08272518962621689
# Training loss for 1160 epoch: -0.12005379050970078
# Training loss for 1170 epoch: -0.09338895976543427
# Training loss for 1180 epoch: -0.1205606684088707
# Training loss for 1190 epoch: -0.09998650848865509
# Training loss for 1200 epoch: -0.09465775638818741
# Training loss for 1210 epoch: -0.09634492546319962
# Training loss for 1220 epoch: -0.09132125228643417
# Training loss for 1230 epoch: -0.07992641627788544
# Training loss for 1240 epoch: -0.08045537769794464
# Training loss for 1250 epoch: -0.06073868274688721
# Training loss for 1260 epoch: -0.08810026943683624
# Training loss for 1270 epoch: -0.07743141800165176
# Training loss for 1280 epoch: -0.06064262241125107
# Training loss for 1290 epoch: -0.11091122776269913
# Training loss for 1300 epoch: -0.10857705771923065
# Training loss for 1310 epoch: -0.06746073067188263
# Training loss for 1320 epoch: -0.04879333823919296
# Training loss for 1330 epoch: -0.0721069797873497
# Training loss for 1340 epoch: -0.061812758445739746
# Training loss for 1350 epoch: -0.10936792194843292
# Training loss for 1360 epoch: -0.10128672420978546
# Training loss for 1370 epoch: -0.09139974415302277
# Training loss for 1380 epoch: -0.09433124214410782
# Training loss for 1390 epoch: -0.10704157501459122
# Training loss for 1400 epoch: -0.08931253105401993
# Training loss for 1410 epoch: -0.10250790417194366
# Training loss for 1420 epoch: -0.10046117007732391
# Training loss for 1430 epoch: -0.09510347992181778
# Training loss for 1440 epoch: -0.07763509452342987
# Training loss for 1450 epoch: -0.07549969851970673
# Training loss for 1460 epoch: -0.08940660953521729
# Training loss for 1470 epoch: -0.10813431441783905
# Training loss for 1480 epoch: -0.08597233146429062
# Training loss for 1490 epoch: -0.1131783276796341
# Training loss for 1500 epoch: -0.0877372995018959
# Training loss for 1510 epoch: -0.04670839384198189
# Training loss for 1520 epoch: -0.0571911558508873
# Training loss for 1530 epoch: -0.08713586628437042
# Training loss for 1540 epoch: -0.0952019914984703
# Training loss for 1550 epoch: -0.06461183726787567
# Training loss for 1560 epoch: -0.08231675624847412
# Training loss for 1570 epoch: -0.07741837203502655
# Training loss for 1580 epoch: -0.044672705233097076
# Training loss for 1590 epoch: -0.0643346756696701
# Training loss for 1600 epoch: -0.07011687755584717
# Training loss for 1610 epoch: -0.08672299236059189
# Training loss for 1620 epoch: -0.09257407486438751
# Training loss for 1630 epoch: -0.106589674949646
# Training loss for 1640 epoch: -0.08528520911931992
# Training loss for 1650 epoch: -0.06699170917272568
# Training loss for 1660 epoch: -0.09230222553014755
# Training loss for 1670 epoch: -0.07055661827325821
# Training loss for 1680 epoch: -0.05503976345062256
# Training loss for 1690 epoch: -0.04404637962579727
# Training loss for 1700 epoch: -0.05795936658978462
# Training loss for 1710 epoch: -0.05047743394970894
# Training loss for 1720 epoch: -0.11033999919891357
# Training loss for 1730 epoch: -0.08884408324956894
# Training loss for 1740 epoch: -0.09124378859996796
# Training loss for 1750 epoch: -0.10345204174518585
# Training loss for 1760 epoch: -0.0970846638083458
# Training loss for 1770 epoch: -0.07983233779668808
# Training loss for 1780 epoch: -0.059659767895936966
# Training loss for 1790 epoch: -0.028252029791474342
# Training loss for 1800 epoch: -0.08385507762432098
# Training loss for 1810 epoch: -0.03356218338012695
# Training loss for 1820 epoch: -0.07678385078907013
# Training loss for 1830 epoch: -0.09067440032958984
# Training loss for 1840 epoch: -0.07072167098522186
# Training loss for 1850 epoch: -0.06512858718633652
# Training loss for 1860 epoch: -0.09512867778539658
# Training loss for 1870 epoch: -0.06857254356145859
# Training loss for 1880 epoch: -0.07897470146417618
# Training loss for 1890 epoch: -0.03135480731725693
# Training loss for 1900 epoch: -0.01676206663250923
# Training loss for 1910 epoch: -0.07239210605621338
# Training loss for 1920 epoch: -0.061140965670347214
# Training loss for 1930 epoch: -0.05863676220178604
# Training loss for 1940 epoch: -0.10390117019414902
# Training loss for 1950 epoch: -0.08838186413049698
# Training loss for 1960 epoch: -0.0516432523727417
# Training loss for 1970 epoch: -0.07295989990234375
# Training loss for 1980 epoch: -0.1031174436211586
# Training loss for 1990 epoch: -0.0448915958404541
# Training loss for 2000 epoch: -0.07536570727825165
# Training loss for 2010 epoch: -0.0752277821302414
# Training loss for 2020 epoch: -0.08543539047241211
# Training loss for 2030 epoch: -0.05060138553380966
# Training loss for 2040 epoch: -0.06241147592663765
# Training loss for 2050 epoch: -0.08029232174158096
# Training loss for 2060 epoch: -0.04372198507189751
# Training loss for 2070 epoch: -0.07008187472820282
# Training loss for 2080 epoch: -0.10703086853027344
# Training loss for 2090 epoch: -0.056484054774045944
# Training loss for 2100 epoch: -0.07254514843225479
# Training loss for 2110 epoch: -0.035988904535770416
# Training loss for 2120 epoch: -0.07035114616155624
# Training loss for 2130 epoch: -0.1044885665178299
# Training loss for 2140 epoch: -0.06053481251001358
# Training loss for 2150 epoch: -0.06410517543554306
# Training loss for 2160 epoch: -0.08650712668895721
# Training loss for 2170 epoch: -0.09828738868236542
# Training loss for 2180 epoch: -0.09147634357213974
# Training loss for 2190 epoch: -0.047925662249326706
# Training loss for 2200 epoch: -0.07615029811859131
# Training loss for 2210 epoch: -0.03683924674987793
# Training loss for 2220 epoch: -0.011490345001220703
# Training loss for 2230 epoch: -0.018714595586061478
# Training loss for 2240 epoch: -0.08407106250524521
# Training loss for 2250 epoch: -0.05510067939758301
# Training loss for 2260 epoch: -0.06409039348363876
# Training loss for 2270 epoch: -0.04306488111615181
# Training loss for 2280 epoch: -0.08090338855981827
# Training loss for 2290 epoch: -0.06243474408984184
# Training loss for 2300 epoch: -0.07960011810064316
# Training loss for 2310 epoch: -0.06384706497192383
# Training loss for 2320 epoch: -0.06870444118976593
# Training loss for 2330 epoch: -0.07095415890216827
# Training loss for 2340 epoch: -0.09325001388788223
# Training loss for 2350 epoch: -0.04820997640490532
# Training loss for 2360 epoch: -0.05931510776281357
# Training loss for 2370 epoch: -0.06303570419549942
# Training loss for 2380 epoch: -0.0732908695936203
# Training loss for 2390 epoch: -0.057303451001644135
# Training loss for 2400 epoch: -0.07178054004907608
# Training loss for 2410 epoch: -0.08664312213659286
# Training loss for 2420 epoch: -0.0920676440000534
# Training loss for 2430 epoch: -0.026529740542173386
# Training loss for 2440 epoch: -0.07894422858953476
# Training loss for 2450 epoch: -0.056647609919309616
# Training loss for 2460 epoch: -0.03660929203033447
# Training loss for 2470 epoch: -0.036583445966243744
# Training loss for 2480 epoch: -0.09196329116821289
# Training loss for 2490 epoch: -0.06036026403307915
# Training loss for 2500 epoch: -0.04496035724878311
# Training loss for 2510 epoch: -0.06214272975921631
# Training loss for 2520 epoch: -0.030095528811216354
# Training loss for 2530 epoch: -0.07838394492864609
# Training loss for 2540 epoch: -0.07099521160125732
# Training loss for 2550 epoch: -0.015418958850204945
# Training loss for 2560 epoch: -0.06280238926410675
# Training loss for 2570 epoch: -0.04148092120885849
# Training loss for 2580 epoch: -0.034105658531188965
# Training loss for 2590 epoch: -0.08175818622112274
# Training loss for 2600 epoch: -0.07581625133752823
# Training loss for 2610 epoch: -0.027310466393828392
# Training loss for 2620 epoch: -0.05206017568707466
# Training loss for 2630 epoch: -0.022237157449126244
# Training loss for 2640 epoch: -0.03846282884478569
# Training loss for 2650 epoch: -0.03501694276928902
# Training loss for 2660 epoch: -0.009579706005752087
# Training loss for 2670 epoch: -0.09257159382104874
# Training loss for 2680 epoch: -0.01712017133831978
# Training loss for 2690 epoch: -0.03399355337023735
# Training loss for 2700 epoch: -0.052811481058597565
# Training loss for 2710 epoch: -0.04819224029779434
# Training loss for 2720 epoch: -0.05892393738031387
# Training loss for 2730 epoch: -0.05391230434179306
# Training loss for 2740 epoch: -0.045182131230831146
# Training loss for 2750 epoch: -0.045065879821777344
# Training loss for 2760 epoch: -0.05975162982940674
# Training loss for 2770 epoch: -0.10154781490564346
# Training loss for 2780 epoch: -0.056394029408693314
# Training loss for 2790 epoch: -0.07530693709850311
# Training loss for 2800 epoch: -0.01195230521261692
# Training loss for 2810 epoch: -0.04042162746191025
# Training loss for 2820 epoch: -0.06246917322278023
# Training loss for 2830 epoch: -0.03402285650372505
# Training loss for 2840 epoch: -0.05526309087872505
# Training loss for 2850 epoch: -0.048400044441223145
# Training loss for 2860 epoch: -0.07459268718957901
# Training loss for 2870 epoch: -0.04457354545593262
# Training loss for 2880 epoch: -0.05964403226971626
# Training loss for 2890 epoch: -0.1040538102388382
# Training loss for 2900 epoch: -0.037534356117248535
# Training loss for 2910 epoch: -0.05926687642931938
# Training loss for 2920 epoch: -0.02987520769238472
# Training loss for 2930 epoch: -0.06475100666284561
# Training loss for 2940 epoch: -0.04200565814971924
# Training loss for 2950 epoch: -0.04819533973932266
# Training loss for 2960 epoch: -0.05860473960638046
# Training loss for 2970 epoch: -0.0556962713599205
# Training loss for 2980 epoch: -0.06167028099298477
# Training loss for 2990 epoch: -0.06261394172906876
# Training loss for 3000 epoch: -0.05134839937090874
# Training loss for 3010 epoch: -0.030617689713835716
# Training loss for 3020 epoch: -0.07943765819072723
# Training loss for 3030 epoch: -0.05254366248846054
# Training loss for 3040 epoch: -0.03832590579986572
# Training loss for 3050 epoch: -0.04331989213824272
# Training loss for 3060 epoch: -0.06017424911260605
# Training loss for 3070 epoch: -0.03206691890954971
# Training loss for 3080 epoch: -0.04134387895464897
# Training loss for 3090 epoch: -0.013160133734345436
# Training loss for 3100 epoch: -0.06842739880084991
# Training loss for 3110 epoch: -0.03478636592626572
# Training loss for 3120 epoch: -0.06575343757867813
# Training loss for 3130 epoch: -0.022712040692567825
# Training loss for 3140 epoch: -0.02980964258313179
# Training loss for 3150 epoch: -0.07837028801441193
# Training loss for 3160 epoch: -0.0030267476104199886
# Training loss for 3170 epoch: -0.05897803232073784
# Training loss for 3180 epoch: -0.050061486661434174
# Training loss for 3190 epoch: -0.021199535578489304
# Training loss for 3200 epoch: -0.0698736160993576
# Training loss for 3210 epoch: -0.0339166633784771
# Training loss for 3220 epoch: -0.046332526952028275
# Training loss for 3230 epoch: -0.049828171730041504
# Training loss for 3240 epoch: -0.021195506677031517
# Training loss for 3250 epoch: -0.04317428916692734
# Training loss for 3260 epoch: -0.05117456987500191
# Training loss for 3270 epoch: -0.04548189789056778
# Training loss for 3280 epoch: -0.06390688568353653
# Training loss for 3290 epoch: -0.037479329854249954
# Training loss for 3300 epoch: -0.06149027496576309
# Training loss for 3310 epoch: -0.05260481685400009
# Training loss for 3320 epoch: 0.009753179736435413
# Training loss for 3330 epoch: -0.04589667171239853
# Training loss for 3340 epoch: -0.031073331832885742
# Training loss for 3350 epoch: -0.05766942352056503
# Training loss for 3360 epoch: -0.0780414342880249
# Training loss for 3370 epoch: -0.04837343841791153
# Training loss for 3380 epoch: -0.05566291883587837
# Training loss for 3390 epoch: -0.05181457847356796
# Training loss for 3400 epoch: -0.06864187866449356
# Training loss for 3410 epoch: -0.05045421048998833
# Training loss for 3420 epoch: -0.0410299077630043
# Training loss for 3430 epoch: -0.05310790613293648
# Training loss for 3440 epoch: -0.04903104156255722
# Training loss for 3450 epoch: -0.0615849494934082
# Training loss for 3460 epoch: -0.02930579148232937
# Training loss for 3470 epoch: -0.03483150154352188
# Training loss for 3480 epoch: -0.031770966947078705
# Training loss for 3490 epoch: -0.04882519319653511
# Training loss for 3500 epoch: -0.034221697598695755
# Training loss for 3510 epoch: -0.00848686695098877
# Training loss for 3520 epoch: -0.04223189502954483
# Training loss for 3530 epoch: -0.0654531717300415
# Training loss for 3540 epoch: -0.048692844808101654
# Training loss for 3550 epoch: -0.03768618032336235
# Training loss for 3560 epoch: -0.03738594055175781
# Training loss for 3570 epoch: -0.03197331354022026
# Training loss for 3580 epoch: -0.057474564760923386
# Training loss for 3590 epoch: 0.013312553986907005
# Training loss for 3600 epoch: -0.018512845039367676
# Training loss for 3610 epoch: -0.06377039104700089
# Training loss for 3620 epoch: -0.07480935752391815
# Training loss for 3630 epoch: -0.08869127929210663
# Training loss for 3640 epoch: -0.05297698825597763
# Training loss for 3650 epoch: -0.06954505294561386
# Training loss for 3660 epoch: -0.05084562301635742
# Training loss for 3670 epoch: -0.048146627843379974
# Training loss for 3680 epoch: -0.06551768630743027
# Training loss for 3690 epoch: -0.03713500499725342
# Training loss for 3700 epoch: -0.05448298528790474
# Training loss for 3710 epoch: -0.024974275380373
# Training loss for 3720 epoch: -0.05133058875799179
# Training loss for 3730 epoch: -0.012370658107101917
# Training loss for 3740 epoch: -0.02416989766061306
# Training loss for 3750 epoch: -0.047568392008543015
# Training loss for 3760 epoch: -0.03883771970868111
# Training loss for 3770 epoch: -0.023862838745117188
# Training loss for 3780 epoch: -0.007860732264816761
# Training loss for 3790 epoch: -0.036757636815309525
# Training loss for 3800 epoch: -0.060848213732242584
# Training loss for 3810 epoch: -0.04093818739056587
# Training loss for 3820 epoch: -0.0122284647077322
# Training loss for 3830 epoch: -0.030551433563232422
# Training loss for 3840 epoch: -0.019421840086579323
# Training loss for 3850 epoch: -0.09559614956378937
# Training loss for 3860 epoch: 0.005695462226867676
# Training loss for 3870 epoch: -0.06921527534723282
# Training loss for 3880 epoch: -0.04680926725268364
# Training loss for 3890 epoch: -0.07664117962121964
# Training loss for 3900 epoch: -0.07168705761432648
# Training loss for 3910 epoch: -0.03445925563573837
# Training loss for 3920 epoch: -0.035747528076171875
# Training loss for 3930 epoch: -0.05234496667981148
# Training loss for 3940 epoch: -0.055146168917417526
# Training loss for 3950 epoch: -0.03484196588397026
# Training loss for 3960 epoch: -0.03363065794110298
# Training loss for 3970 epoch: -0.08457207679748535
# Training loss for 3980 epoch: -0.056427933275699615
# Training loss for 3990 epoch: -0.028126072138547897
# Training loss for 4000 epoch: -0.04665977880358696
# Training loss for 4010 epoch: -0.03080611303448677
# Training loss for 4020 epoch: -0.017447566613554955
# Training loss for 4030 epoch: -0.08281507343053818
# Training loss for 4040 epoch: -0.04816870763897896
# Training loss for 4050 epoch: -0.021604061126708984
# Training loss for 4060 epoch: -0.027837133035063744
# Training loss for 4070 epoch: -0.037815190851688385
# Training loss for 4080 epoch: -0.0066652060486376286
# Training loss for 4090 epoch: -0.06688053905963898
# Training loss for 4100 epoch: -0.014464044943451881
# Training loss for 4110 epoch: -0.062419869005680084
# Training loss for 4120 epoch: -0.06426636874675751
# Training loss for 4130 epoch: -0.03396632522344589
# Training loss for 4140 epoch: -0.06736192852258682
# Training loss for 4150 epoch: -0.06942198425531387
# Training loss for 4160 epoch: -0.003856873605400324
# Training loss for 4170 epoch: -0.04231908172369003
# Training loss for 4180 epoch: -0.03286099433898926
# Training loss for 4190 epoch: -0.02731294557452202
# Training loss for 4200 epoch: -0.013348579406738281
# Training loss for 4210 epoch: -0.03409869596362114
# Training loss for 4220 epoch: -0.01183781586587429
# Training loss for 4230 epoch: -0.027171993628144264
# Training loss for 4240 epoch: -0.017075181007385254
# Training loss for 4250 epoch: -0.019499707967042923
# Training loss for 4260 epoch: -0.016948889940977097
# Training loss for 4270 epoch: -0.020732522010803223
# Training loss for 4280 epoch: -0.08454930782318115
# Training loss for 4290 epoch: -0.04850048944354057
# Training loss for 4300 epoch: -0.0695381611585617
# Training loss for 4310 epoch: -0.050800275057554245
# Training loss for 4320 epoch: -0.02871096134185791
# Training loss for 4330 epoch: -0.003509140107780695
# Training loss for 4340 epoch: -0.061934780329465866
# Training loss for 4350 epoch: -0.05564682558178902
# Training loss for 4360 epoch: -0.06567516177892685
# Training loss for 4370 epoch: -0.03880755975842476
# Training loss for 4380 epoch: -0.0449814572930336
# Training loss for 4390 epoch: -0.025344442576169968
# Training loss for 4400 epoch: -0.05956442281603813
# Training loss for 4410 epoch: -0.03430609777569771
# Training loss for 4420 epoch: -0.030682921409606934
# Training loss for 4430 epoch: -0.0353960283100605
# Training loss for 4440 epoch: -0.08019478619098663
# Training loss for 4450 epoch: 0.007088684942573309
# Training loss for 4460 epoch: -0.054603077471256256
# Training loss for 4470 epoch: -0.04011871665716171
# Training loss for 4480 epoch: -0.025378774851560593
# Training loss for 4490 epoch: -0.061598919332027435
# Training loss for 4500 epoch: -0.023919105529785156
# Training loss for 4510 epoch: -0.024909043684601784
# Training loss for 4520 epoch: -0.07046405971050262
# Training loss for 4530 epoch: -0.05159025266766548
# Training loss for 4540 epoch: -0.04532830789685249
# Training loss for 4550 epoch: -0.0025841952301561832
# Training loss for 4560 epoch: -0.05659685283899307
# Training loss for 4570 epoch: -0.022008825093507767
# Training loss for 4580 epoch: -0.05108175426721573
# Training loss for 4590 epoch: -0.011769342236220837
# Training loss for 4600 epoch: -0.030008841305971146
# Training loss for 4610 epoch: -0.06245625019073486
# Training loss for 4620 epoch: -0.016179442405700684
# Training loss for 4630 epoch: -0.07412707805633545
# Training loss for 4640 epoch: -0.03498036786913872
# Training loss for 4650 epoch: -0.03462541103363037
# Training loss for 4660 epoch: 0.0072660683654248714
# Training loss for 4670 epoch: -0.06282627582550049
# Training loss for 4680 epoch: -0.02095336839556694
# Training loss for 4690 epoch: -0.04905235767364502
# Training loss for 4700 epoch: -0.04465663433074951
# Training loss for 4710 epoch: -0.005006694700568914
# Training loss for 4720 epoch: -0.019178081303834915
# Training loss for 4730 epoch: -0.016414856538176537
# Training loss for 4740 epoch: 0.002462673233821988
# Training loss for 4750 epoch: -0.02709507942199707
# Training loss for 4760 epoch: -0.05952880531549454
# Training loss for 4770 epoch: -0.00074429513188079
# Training loss for 4780 epoch: -0.02036118507385254
# Training loss for 4790 epoch: -0.06090514734387398
# Training loss for 4800 epoch: -0.03126387670636177
# Training loss for 4810 epoch: -0.03941643238067627
# Training loss for 4820 epoch: -0.045659732073545456
# Training loss for 4830 epoch: -0.03752558305859566
# Training loss for 4840 epoch: -0.028393125161528587
# Training loss for 4850 epoch: -0.043753720819950104
# Training loss for 4860 epoch: -0.044588781893253326
# Training loss for 4870 epoch: -0.03301053121685982
# Training loss for 4880 epoch: -0.017299914732575417
# Training loss for 4890 epoch: -0.03959522396326065
# Training loss for 4900 epoch: -0.010432004928588867
# Training loss for 4910 epoch: -0.02747020684182644
# Training loss for 4920 epoch: -0.06444074958562851
# Training loss for 4930 epoch: -0.00324404239654541
# Training loss for 4940 epoch: -0.029204821214079857
# Training loss for 4950 epoch: -0.01525101624429226
# Training loss for 4960 epoch: -0.03664867952466011
# Training loss for 4970 epoch: -0.029908204451203346
# Training loss for 4980 epoch: -0.01896071434020996
# Training loss for 4990 epoch: -0.010873603634536266
# Training loss for 5000 epoch: -0.010105681605637074
# CPU times: user 38min 48s, sys: 1min 22s, total: 40min 10s
# Wall time: 40min 5s

# %%
len(loss_)
# Out:
# 320

# %%
# Plot loss function
loss_at_epoch = np.array(loss_at_epoch)
plt.plot(range(len(loss_at_epoch[50:])),loss_at_epoch[50:])
# plt.yscale('log')
plt.xlabel(r'$\rm epoch$')
plt.ylabel(r'$\rm loss$');

# %% [markdown]
# ## Training saturated at 0.5. Need to lower.

# %% [markdown]
# The network is now trained (seemingly).

# %%
torch.save(rbm.state_dict(),'./L_'+str(L)+'_T_'+str(T)+'_nonsymmRBM.pt')

# %%
rbm = RBM(n_vis,n_hin,k=1)
# rbm.load_state_dict(torch.load('./L_6_T_4.0_nonsymmRBM.pt'))
rbm.load_state_dict(torch.load('./L_'+str(L)+'_T_'+str(T)+'_nonsymmRBM.pt'))
rbm.eval()
# Out:
# RBM()

# %% [markdown]
# ## Sampling Ising configurations from model

# %% [markdown]
# With our trained model, we now want to sample a new set of Ising configuraions according to the model probability distribution.

# %% [markdown]
# ### Plot random walk

# %%
num_walks = 8 # number of independent random walks desired when sampling

# %%
v_in = torch.bernoulli(torch.rand(num_walks,n_vis))

# %%
# %%time

files = []
filenames = []
for w in range(num_walks):
    # Open file for writing
    filename = 'L_'+str(L)+'_T_'+str(T)+'_rbm_walk_'+str(w)+'.dat'
    file = open(filename, "w")
    header = "#L=%d, T=%.2f \n# E     M \n"
    file.write(header)
    files.append(file)
    filenames.append(filename)

# Initialize quantities to measure
E = np.zeros(num_walks)
M = np.zeros(num_walks)

# Set simulation parameters
bins_wanted = 1000 # number of samples to generate
# sweep = L**2 # size of one Monte Carlo sweep
sweep = 1 # size of one Monte Carlo sweep
bin_size = 5 # number of samples  to 
skip = 20 # sweeps performed between measurement

equilibration_steps = 5000

bins_written = 0 # counts how many bins have been written to disk
measurement_ctr = 0 # to track if we can write to disk
m = 0 # iteration counter
while(bins_written<bins_wanted):
    
    m +=1
    
    # Update input and generated visible vector
    v_in, v_gen = rbm(v_in.view(-1, N_spins))
    # v_in.
    # v_in = v_gen
    
    v_in = v_in.detach()
    v_gen =v_gen.detach()
    v_in = v_gen
    
    # Perform measurement
    if (m%(sweep*skip)==0 and m>equilibration_steps):
        
        # Unflatten and replace 0's with -1's
        ising_lattice = v_gen.detach().numpy().reshape((num_walks,L,L))

        ising_lattice[ising_lattice==0] = -1
        
        for w in range(num_walks):
            E[w] += ising_analysis.get_energy(ising_lattice[w],L)
            M[w] += ising_analysis.get_magnetization(ising_lattice[w],L)
        
        measurement_ctr += 1
        
        if (measurement_ctr==bin_size):
            
            # Write to disk
            for w in range(num_walks):
                files[w].write('%.2f %.2f \n'%(E[w]/bin_size,M[w]/bin_size))
            
            bins_written += 1
        
            # Reset counters and accumulators
            measurement_ctr = 0
            E = np.zeros(num_walks)
            M = np.zeros(num_walks)

            if bins_written%1000==0:
                print("bins_written: ",bins_written)
            
# Close files           
for w in range(num_walks):
    files[w].close()
# Out:
# bins_written:  1000
# CPU times: user 22 s, sys: 118 ms, total: 22.1 s
# Wall time: 22.3 s

# %%
# plt.rcParams["figure.figsize"] = [7.00*2, 3.50*2]
# plt.rcParams["figure.autolayout"] = True

# %%
for w in range(num_walks):
    
    filename = 'L_'+str(L)+'_T_'+str(T)+'_rbm_walk_'+str(w)+'.dat'

    rbm_data = np.loadtxt(filename)
    rbm_E = rbm_data[:,0]
    rbm_M = rbm_data[:,1]

    rbm_e = rbm_E/L**2
    rbm_m = rbm_M/L**2
    
    # Plot running average of energy per spin
    plt.plot(np.arange(rbm_e.shape[0]),np.cumsum(rbm_e)/np.arange(1,rbm_e.shape[0]+1))

plt.xlabel('sample number')
plt.ylabel(r'$E/N$')

plt.axhline(ising_analysis.e_exact_func(T),zorder=5,color='k')
# plt.savefig('e_without_abs.pdf',dpi=300)

# %%
for w in range(num_walks):
    
    filename = 'L_'+str(L)+'_T_'+str(T)+'_rbm_walk_'+str(w)+'.dat'

    rbm_data = np.loadtxt(filename)
    rbm_M = rbm_data[:,1]

    rbm_m = rbm_M/L**2
    
    # Plot running average of energy per spin
    plt.plot(np.arange(rbm_m.shape[0]),np.cumsum(rbm_m)/np.arange(1,rbm_m.shape[0]+1))

plt.xlabel('sample number')
plt.ylabel(r'$M/N$')

plt.axhline(np.nan_to_num(ising_analysis.m_exact_func(T)),zorder=5,color='k')
# plt.savefig('e_without_abs.pdf',dpi=300)
# Out:
# ../ising_analysis.py:103: RuntimeWarning: invalid value encountered in double_scalars
#   return (1-(1-np.tanh(K)**2)**4/(16*np.tanh(K)**4))**(1/8)

# %%
plt.rcParams["figure.figsize"] = [7.00*3, 3.50*3]
plt.rcParams["figure.autolayout"] = True
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$i$')
plt.imshow(rbm.W.detach().numpy())
plt.colorbar()
# plt.clim(0,1)

# %% [markdown]
# # References

# %% [markdown]
# https://towardsdatascience.com/how-to-use-datasets-and-dataloader-in-pytorch-for-custom-text-data-270eed7f7c00
#
# https://blog.paperspace.com/beginners-guide-to-boltzmann-machines-pytorch/
#
# https://stats.stackexchange.com/questions/114844/how-to-compute-the-free-energy-of-a-rbm-given-its-energy
#
# https://github.com/lisa-lab/DeepLearningTutorials/blob/master/code/rbm.py#L127
#
# https://medium.com/machine-learning-researcher/boltzmann-machine-c2ce76d94da5
